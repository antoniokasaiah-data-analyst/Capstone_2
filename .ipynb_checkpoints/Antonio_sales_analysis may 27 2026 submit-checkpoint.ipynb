# %% [markdown]
# ## Capstone 2 Python
#
#
# ### This project analyzes sales data for the fictional company EmporiUm using Python, Pandas, NumPy, and Matplotlib within a Jupyter Notebook environment.
# ### My assigned territories for this analysis are Colorado in the western region and South Carolina in southern region. I will compare sales performance, customer activity, store rankings, product trends, and monthly revenue to identify business insights and marketing opportunities.
# ### The project also includes data cleaning, data visualization, and business recommendations supported by charts, along with a final presentation and video walkthrough of the analysis.

# %% [markdown]
# ### Importing Python Libraries

# %%
# Down below I have imported and assigned an alias to three Python Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp

# %% [markdown]
# ### Creating a Class and Importing Datasets

# %%
# I chose to use a class for this project because the analysis involves multiple related datasets, and a class helps keep all of the data, functions, and analysis organized in one structured project object. 
# Using a class also makes the code cleaner, easier to manage, and more scalable as I continue adding data cleaning, visualizations, and business analysis throughout the capstone project.
# def creates the function
# functions in a class are called methods
# __init__ is a special function that automatically runs when an object is created from a class.
# Also known as the construcotr method
# self is a temporary parameter that is references an object
# self.storesales is an attribute
# attributes hold values than can be used in objects 
# attributes are similar to variables
# pd.read_csv() allows me to import csv data into python using the pandas library
# Im storing the csv data in an attriubute to be used by an object later
# Windows files are saved as a single backslash but python only reads forward and double back slashes 
# You have to manually change the single backslashes to single forward slashes or double backslashes
# Created a second method that previews data the first 5 rows from each dataframe 
# A dataframe is a table made up of rows and columns in python
# Created a Thrid Method that shows dataframe(table) information
# () at the end of the method runs the method
# I then created a object then called both both methods using .methodname()  


class EmpAnalysis:

    def __init__(self): 
        self.storesales = pd.read_csv("C:\\Users\\User\\Documents\\Capstone_2\\StoreSales.csv")
        self.storedetails = pd.read_csv("C:\\Users\\User\\Documents\\Capstone_2\\StoreDetail.csv")
        self.products = pd.read_csv("C:\\Users\\User\\Documents\\Capstone_2\\Products.csv")
        self.productcategories = pd.read_csv("C:\\Users\\User\\Documents\\Capstone_2\\ProductCategories.csv")
        self.customer_list = pd.read_csv("C:\\Users\\User\\Documents\\Capstone_2\\customer_list.csv")

    
    def preview_data(self):
        
        print("\nCustomers List ")
        print(self.customer_list.head())

        print("\nProduct Categories ")
        print(self.productcategories.head())

        print("\nProducts")
        print(self.products.head())

        print("\nStore Details")
        print(self.storedetails.head())

        print("\nStores Sales")
        print(self.storesales.head())

    def tableinfo(self):
        
        print("\nCustomers Info ")
        self.customer_list.info()

        print("\nProduct Categories Info ")
        self.productcategories.info()

        print("\nProducts Info")
        self.products.info()

        print("\nStore Details Info")
        self.storedetails.info()

        print("\nStores Sales Info")
        self.storesales.info()

data_info = EmpAnalysis()

data_info.preview_data()
data_info.tableinfo()
# Out:
# Customers List
#      cust_id|date|time|name|email|phone|sms-opt-out
# 0  1|2023-03-15|08:45:12|Rachel|rachel@centralper...
# 1  2|2023-05-22|12:30:45|R. Geller|rossg@centralp...
# 2  3|2023-07-09|18:15:27|Monica Geller|chefmonica...
# 3  4|2023-09-01|21:05:33|Chandler Bing|chandlerb@...
# 4  5|2023-11-18|14:22:10|Joey|howyoudoing@central...
#
# Product Categories
#    CategoryID                  Category SubcategoryID           Subcategory
# 0         120  Technology & Accessories       120-tab               Tablets
# 1         120  Technology & Accessories       120-cal           Calculators
# 2         120  Technology & Accessories       120-sof     Software Download
# 3         120  Technology & Accessories       120-hea            Headphones
# 4         120  Technology & Accessories       120-ext  External Accessories
#
# Products
#     Prod Num                        Product  CategoryID SubcategoryID
# 0  105248-IT               TCL NXTPAPER 10s         120       120-tab
# 1  105249-IT  Dell Latitude 7320 Detachable         120       120-tab
# 2  105250-IT                     Realme Pad         120       120-tab
# 3  105251-IT             Lenovo Tab P12 Pro         120       120-tab
# 4  105252-IT        Microsoft Surface Pro 9         120       120-tab
#
# Store Details
#   Store Location     State  Store ID Territory Manager Region  Region Director
# 0         Aurora  Colorado       701          Jim Heck   West  Cassie Chambers
# 1       Berthoud  Colorado       702          Jim Heck   West  Cassie Chambers
# 2        Boulder  Colorado       703          Jim Heck   West  Cassie Chambers
# 3    Castle Rock  Colorado       704          Jim Heck   West  Cassie Chambers
# 4         Denver  Colorado       705          Jim Heck   West  Cassie Chambers
#
# Stores Sales
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount
# 0         1/1/2022       702        NaN  105349-M         8.00
# 1         1/1/2022       704        NaN  105350-T       144.00
# 2         1/1/2022       705        NaN  105351-M        44.00
# 3         1/1/2022       705        NaN  105352-M        47.61
# 4         1/1/2022       705        NaN  105353-A        20.36
#
# Customers Info
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 1 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   cust_id|date|time|name|email|phone|sms-opt-out   521 non-null    str
# dtypes: str(1)
# memory usage: 4.2 KB
#
# Product Categories Info
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB
#
# Products Info
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB
#
# Store Details Info
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB
#
# Stores Sales Info
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %% [markdown]
# ### Core Marketing Analysis

# %% [markdown]
# #### Question 1:
# ##### Who are the territory managers for the sales territories assigned? What are the store IDs and cities
# ##### for the stores in each assigned sales territory?

# %% [markdown]
# #### Step 1
# ##### Identify the dataframe(table) your going to filter data from.

# %%
# Using an object created from the class we can see a preview of the first 5 rows in each dataframe(table) I imported using pandas
# I then can identify which tables are needed to answer this question.
# I've identified that I need to use the Store details dataframe(table).
# It has the 6 columns that include Store Location,State,Store ID,Territory Manager,Region ,Region Director
# After finding the table I need to create a new method in the class created earlier 
# If I created a a method outside of the codeblock the class is in, I want be able to use the previuos methods
# But for the sake of this project I'll do both since it is required 

data_info.preview_data()
# Out:
# Customers List
#      cust_id|date|time|name|email|phone|sms-opt-out
# 0  1|2023-03-15|08:45:12|Rachel|rachel@centralper...
# 1  2|2023-05-22|12:30:45|R. Geller|rossg@centralp...
# 2  3|2023-07-09|18:15:27|Monica Geller|chefmonica...
# 3  4|2023-09-01|21:05:33|Chandler Bing|chandlerb@...
# 4  5|2023-11-18|14:22:10|Joey|howyoudoing@central...
#
# Product Categories
#    CategoryID                  Category SubcategoryID           Subcategory
# 0         120  Technology & Accessories       120-tab               Tablets
# 1         120  Technology & Accessories       120-cal           Calculators
# 2         120  Technology & Accessories       120-sof     Software Download
# 3         120  Technology & Accessories       120-hea            Headphones
# 4         120  Technology & Accessories       120-ext  External Accessories
#
# Products
#     Prod Num                        Product  CategoryID SubcategoryID
# 0  105248-IT               TCL NXTPAPER 10s         120       120-tab
# 1  105249-IT  Dell Latitude 7320 Detachable         120       120-tab
# 2  105250-IT                     Realme Pad         120       120-tab
# 3  105251-IT             Lenovo Tab P12 Pro         120       120-tab
# 4  105252-IT        Microsoft Surface Pro 9         120       120-tab
#
# Store Details
#   Store Location     State  Store ID Territory Manager Region  Region Director
# 0         Aurora  Colorado       701          Jim Heck   West  Cassie Chambers
# 1       Berthoud  Colorado       702          Jim Heck   West  Cassie Chambers
# 2        Boulder  Colorado       703          Jim Heck   West  Cassie Chambers
# 3    Castle Rock  Colorado       704          Jim Heck   West  Cassie Chambers
# 4         Denver  Colorado       705          Jim Heck   West  Cassie Chambers
#
# Stores Sales
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount
# 0         1/1/2022       702        NaN  105349-M         8.00
# 1         1/1/2022       704        NaN  105350-T       144.00
# 2         1/1/2022       705        NaN  105351-M        44.00
# 3         1/1/2022       705        NaN  105352-M        47.61
# 4         1/1/2022       705        NaN  105353-A        20.36

# %% [markdown]
# #### Step 2
# ##### Create a new method that filters columns.

# %%
# _____________________  Notes  _______________________________________________________________________

# Create a new method
# Assign a variable to the code that filters state by Colorado and South Carolina
# When you assign a variable to values the values are stored in the variable
# For this code to be accessed again with ease its needs to be stored as an attribute 
# or I'll have to rewite the code evry time
# self is a temporary parameter in the method that can be placeholder for object
# Im assigning the function to the code using =
# The code selects the state column and and matches it the the value Colorado and South Carolina
# | means or in python
# the code reads select all rows that have Colorado or South Carolina in the State column

# Filtering Columns
# Create another attribute 
# assign the attribute to to the previous attribute
# filter the previuos attribute for " Store Location","State","Store ID","Territory Manager"
# now the attribute only holds values that are in these 4 columns
# adding the method to to the class
# Python treats every codeblock in jupyter as a stand alone codeblock 
# so new mehtods that you create are not created on the class which makes them functions 
# you have to manually add them to the class
# you do this by assigning the function to the class like an attribute to a object
# add the print statement in the method so you dont have to add it later outside the method
# Once done you can assign it to a object 
# Then call the method 
# Using a for loop to print results
# Allows you to iterate through each index(number placement for row in table) 
# x allows you to iterate through values in the row
# x{state} means locate the value in this row under the state column
# These are done using the itterows() dataframe method in python
# The f strings allows you to add comments and varaibles to a print statement

# ______________________________________________________________________________________________________________

# Filter Territories

def filtered_territory_analysis(self):
    
    self.filtered_territory_data = self.storedetails[
        (self.storedetails["State"] == "Colorado") |
        (self.storedetails["State"] == "South Carolina") ]

# filter Columns
    
    self.filtered_territory_columns = self.filtered_territory_data[
        ["Store Location","State","Store ID","Territory Manager"]]

    
# Printing Results 
    print(self.filtered_territory_columns)
    print("\n── Assigned Territory Analysis ─────────────────────────")

    for index, x in self.filtered_territory_columns.iterrows():

        print(
            f"\nStore Record #{index}"
            f"\nState: {x['State']}"
            f"\nTerritory Manager: {x['Territory Manager']}"
            f"\nStore ID: {x['Store ID']}"
            f"\nCity: {x['Store Location']}"
        )
# Assigning Function to class

EmpAnalysis.filtered_territory_analysis = filtered_territory_analysis

# Use previuos object or make a new one

data_info.filtered_territory_analysis()
# Out:
#     Store Location           State  Store ID Territory Manager
# 0           Aurora        Colorado       701          Jim Heck
# 1         Berthoud        Colorado       702          Jim Heck
# 2          Boulder        Colorado       703          Jim Heck
# 3      Castle Rock        Colorado       704          Jim Heck
# 4           Denver        Colorado       705          Jim Heck
# 5        Englewood        Colorado       706          Jim Heck
# 6     Fort Collins        Colorado       707          Jim Heck
# 7   Grand Junction        Colorado       708          Jim Heck
# 8          Greeley        Colorado       709          Jim Heck
# 9        Lafayette        Colorado       710          Jim Heck
# 10       Littleton        Colorado       711          Jim Heck
# 11        Loveland        Colorado       712          Jim Heck
# 12        Milliken        Colorado       713          Jim Heck
# 13      New Castle        Colorado       714          Jim Heck
# 14          Parker        Colorado       715          Jim Heck
# 15         Sedalia        Colorado       716          Jim Heck
# 16        Thornton        Colorado       717          Jim Heck
# 17     Wheat Ridge        Colorado       718          Jim Heck
# 98      Charleston  South Carolina       852        Len Jensen
# 99      Greenville  South Carolina       853        Len Jensen
#
# ── Assigned Territory Analysis ─────────────────────────
#
# Store Record #0
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 701
# City: Aurora
#
# Store Record #1
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 702
# City: Berthoud
#
# Store Record #2
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 703
# City: Boulder
#
# Store Record #3
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 704
# City: Castle Rock
#
# Store Record #4
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 705
# City: Denver
#
# Store Record #5
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 706
# City: Englewood
#
# Store Record #6
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 707
# City: Fort Collins
#
# Store Record #7
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 708
# City: Grand Junction
#
# Store Record #8
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 709
# City: Greeley
#
# Store Record #9
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 710
# City: Lafayette
#
# Store Record #10
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 711
# City: Littleton
#
# Store Record #11
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 712
# City: Loveland
#
# Store Record #12
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 713
# City: Milliken
#
# Store Record #13
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 714
# City: New Castle
#
# Store Record #14
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 715
# City: Parker
#
# Store Record #15
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 716
# City: Sedalia
#
# Store Record #16
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 717
# City: Thornton
#
# Store Record #17
# State: Colorado
# Territory Manager: Jim Heck
# Store ID: 718
# City: Wheat Ridge
#
# Store Record #98
# State: South Carolina
# Territory Manager: Len Jensen
# Store ID: 852
# City: Charleston
#
# Store Record #99
# State: South Carolina
# Territory Manager: Len Jensen
# Store ID: 853
# City: Greenville

# %% [markdown]
# #### Territory Analysis Summary
#
# The analysis identified all stores located within the assigned sales territories of Colorado and South Carolina. Colorado stores are managed by Jim Heck, while South Carolina stores are managed by Len Jensen.
#
# The filtered dataframe displayed the territory manager, store ID, and city location for each assigned store. A total of 18 stores were identified in Colorado and 2 stores were identified in South Carolina.

# %% [markdown]
# #### Question 2
# ##### What is monthly total revenue for in-store sales in each of the two sales territories, over the full
# ##### period covered by the data?

# %% [markdown]
# #### Step 1 Identify what tables are needed to answer this question.

# %%
# use tableinfo to find information about tables

data_info.tableinfo()
# Out:
# Customers Info
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 1 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   cust_id|date|time|name|email|phone|sms-opt-out   521 non-null    str
# dtypes: str(1)
# memory usage: 4.2 KB
#
# Product Categories Info
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB
#
# Products Info
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB
#
# Store Details Info
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB
#
# Stores Sales Info
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %% [markdown]
# #### Step 2
# ##### Merge Dataframes(tables), Modify Dataframe, Filter by Territories

# %%
#________ Notes ________________________________________________________________________________________________

# continue by creating mehthods associated with the EmpAnalysis class 
# identify the tables needed for for question
# Join tables using pd.merge from pandas
# using the object data_info.tableinfo() created earlier I can find the the data type and name of column
# In python, you need the same name and data type to join tables 
# The two tables Im going to use are storedetails and storesales
# to merge dataframes you need to store them in a variable or a attribute( I used an attribute)
# Next the column stored in the attribute needs to be converted to the datetime data type using pd.to_datetime
# Then the attribute can be retrieve the month name using dt.month_name()
# Then the attribute can be retrieve the Year using dt.year
# This creates two new columns Month and Year 
# Group By month, year and state columns using the .groupby datarame method then find the sum sales of each group
# When using a dataframe method you dont have to specify the library your calling the method/function from
# now add this method to the class 


#_______________________________________________________________________________________________________________

def east_south_monthly_revenue(self):

# Merging dataframes(tables) using an attribute 
    
    self.table_merge = pd.merge(
        self.storedetails,
        self.storesales,
        on = "Store ID")
    
# Convert Transaction Date column to datetime
    
    self.table_merge["Transaction Date"] = pd.to_datetime(
        self.table_merge["Transaction Date"])

# Create Month and Year column from Transaction Date
    
    self.table_merge["Month"] = self.table_merge[
        "Transaction Date"].dt.month_name()
 
    self.table_merge["Year"] = self.table_merge[
        "Transaction Date"].dt.year
    
# Filtering Territories
    
    self.filter_merge = self.table_merge[
        (self.table_merge["State"] == "South Carolina") |
        (self.table_merge["State"] == "Colorado") ]

# Grouping By Month,State,and Year 

    self.grouped_merge = self.filter_merge.groupby(
        ["Year","Month","State"])["Sale Amount"].sum()

# Printing outputs

    print("\n── Monthly Territory Revenue Analysis For Each Year ─────────────────")

    for (Year, Month, State), revenue in self.grouped_merge.items():

        print(
            f"\nYear: {Year}"
            f"\nMonth: {Month}"
            f"\nTerritory: {State}"
        f"\nTotal Revenue: ${revenue:,.2f}")

# Assigning Function to class

EmpAnalysis.east_south_monthly_revenue = east_south_monthly_revenue

# Use previuos object or make a new one

data_info.east_south_monthly_revenue()
# Out:
# ── Monthly Territory Revenue Analysis For Each Year ─────────────────
#
# Year: 2022
# Month: April
# Territory: Colorado
# Total Revenue: $89,350.31
#
# Year: 2022
# Month: April
# Territory: South Carolina
# Total Revenue: $8,929.63
#
# Year: 2022
# Month: August
# Territory: Colorado
# Total Revenue: $87,058.36
#
# Year: 2022
# Month: August
# Territory: South Carolina
# Total Revenue: $8,916.43
#
# Year: 2022
# Month: December
# Territory: Colorado
# Total Revenue: $78,541.63
#
# Year: 2022
# Month: December
# Territory: South Carolina
# Total Revenue: $8,360.87
#
# Year: 2022
# Month: February
# Territory: Colorado
# Total Revenue: $80,315.69
#
# Year: 2022
# Month: February
# Territory: South Carolina
# Total Revenue: $9,763.98
#
# Year: 2022
# Month: January
# Territory: Colorado
# Total Revenue: $77,950.98
#
# Year: 2022
# Month: January
# Territory: South Carolina
# Total Revenue: $9,640.38
#
# Year: 2022
# Month: July
# Territory: Colorado
# Total Revenue: $94,048.49
#
# Year: 2022
# Month: July
# Territory: South Carolina
# Total Revenue: $13,083.78
#
# Year: 2022
# Month: June
# Territory: Colorado
# Total Revenue: $86,847.70
#
# Year: 2022
# Month: June
# Territory: South Carolina
# Total Revenue: $7,196.23
#
# Year: 2022
# Month: March
# Territory: Colorado
# Total Revenue: $82,516.36
#
# Year: 2022
# Month: March
# Territory: South Carolina
# Total Revenue: $8,366.63
#
# Year: 2022
# Month: May
# Territory: Colorado
# Total Revenue: $94,892.89
#
# Year: 2022
# Month: May
# Territory: South Carolina
# Total Revenue: $5,396.03
#
# Year: 2022
# Month: November
# Territory: Colorado
# Total Revenue: $76,920.06
#
# Year: 2022
# Month: November
# Territory: South Carolina
# Total Revenue: $8,355.29
#
# Year: 2022
# Month: October
# Territory: Colorado
# Total Revenue: $78,706.96
#
# Year: 2022
# Month: October
# Territory: South Carolina
# Total Revenue: $10,330.27
#
# Year: 2022
# Month: September
# Territory: Colorado
# Total Revenue: $84,206.09
#
# Year: 2022
# Month: September
# Territory: South Carolina
# Total Revenue: $8,155.79
#
# Year: 2023
# Month: April
# Territory: Colorado
# Total Revenue: $131,835.33
#
# Year: 2023
# Month: April
# Territory: South Carolina
# Total Revenue: $9,587.55
#
# Year: 2023
# Month: August
# Territory: Colorado
# Total Revenue: $132,936.24
#
# Year: 2023
# Month: August
# Territory: South Carolina
# Total Revenue: $12,616.78
#
# Year: 2023
# Month: December
# Territory: Colorado
# Total Revenue: $112,438.65
#
# Year: 2023
# Month: December
# Territory: South Carolina
# Total Revenue: $12,742.44
#
# Year: 2023
# Month: February
# Territory: Colorado
# Total Revenue: $118,165.45
#
# Year: 2023
# Month: February
# Territory: South Carolina
# Total Revenue: $14,067.77
#
# Year: 2023
# Month: January
# Territory: Colorado
# Total Revenue: $127,097.69
#
# Year: 2023
# Month: January
# Territory: South Carolina
# Total Revenue: $13,558.82
#
# Year: 2023
# Month: July
# Territory: Colorado
# Total Revenue: $137,070.84
#
# Year: 2023
# Month: July
# Territory: South Carolina
# Total Revenue: $10,441.57
#
# Year: 2023
# Month: June
# Territory: Colorado
# Total Revenue: $110,745.70
#
# Year: 2023
# Month: June
# Territory: South Carolina
# Total Revenue: $9,332.28
#
# Year: 2023
# Month: March
# Territory: Colorado
# Total Revenue: $113,336.10
#
# Year: 2023
# Month: March
# Territory: South Carolina
# Total Revenue: $13,635.31
#
# Year: 2023
# Month: May
# Territory: Colorado
# Total Revenue: $126,201.30
#
# Year: 2023
# Month: May
# Territory: South Carolina
# Total Revenue: $10,674.71
#
# Year: 2023
# Month: November
# Territory: Colorado
# Total Revenue: $122,127.52
#
# Year: 2023
# Month: November
# Territory: South Carolina
# Total Revenue: $10,414.83
#
# Year: 2023
# Month: October
# Territory: Colorado
# Total Revenue: $118,913.30
#
# Year: 2023
# Month: October
# Territory: South Carolina
# Total Revenue: $18,688.18
#
# Year: 2023
# Month: September
# Territory: Colorado
# Total Revenue: $137,022.60
#
# Year: 2023
# Month: September
# Territory: South Carolina
# Total Revenue: $10,502.52
#
# Year: 2024
# Month: April
# Territory: Colorado
# Total Revenue: $124,228.43
#
# Year: 2024
# Month: April
# Territory: South Carolina
# Total Revenue: $10,615.33
#
# Year: 2024
# Month: August
# Territory: Colorado
# Total Revenue: $139,385.22
#
# Year: 2024
# Month: August
# Territory: South Carolina
# Total Revenue: $10,524.22
#
# Year: 2024
# Month: December
# Territory: Colorado
# Total Revenue: $127,097.69
#
# Year: 2024
# Month: December
# Territory: South Carolina
# Total Revenue: $13,558.82
#
# Year: 2024
# Month: February
# Territory: Colorado
# Total Revenue: $104,570.81
#
# Year: 2024
# Month: February
# Territory: South Carolina
# Total Revenue: $13,574.66
#
# Year: 2024
# Month: January
# Territory: Colorado
# Total Revenue: $130,507.83
#
# Year: 2024
# Month: January
# Territory: South Carolina
# Total Revenue: $15,392.13
#
# Year: 2024
# Month: July
# Territory: Colorado
# Total Revenue: $132,936.24
#
# Year: 2024
# Month: July
# Territory: South Carolina
# Total Revenue: $12,616.78
#
# Year: 2024
# Month: June
# Territory: Colorado
# Total Revenue: $131,379.21
#
# Year: 2024
# Month: June
# Territory: South Carolina
# Total Revenue: $10,131.94
#
# Year: 2024
# Month: March
# Territory: Colorado
# Total Revenue: $133,808.20
#
# Year: 2024
# Month: March
# Territory: South Carolina
# Total Revenue: $9,646.93
#
# Year: 2024
# Month: May
# Territory: Colorado
# Total Revenue: $116,437.33
#
# Year: 2024
# Month: May
# Territory: South Carolina
# Total Revenue: $9,641.91
#
# Year: 2024
# Month: November
# Territory: Colorado
# Total Revenue: $110,361.93
#
# Year: 2024
# Month: November
# Territory: South Carolina
# Total Revenue: $12,534.59
#
# Year: 2024
# Month: October
# Territory: Colorado
# Total Revenue: $124,204.24
#
# Year: 2024
# Month: October
# Territory: South Carolina
# Total Revenue: $10,622.68
#
# Year: 2024
# Month: September
# Territory: Colorado
# Total Revenue: $116,550.68
#
# Year: 2024
# Month: September
# Territory: South Carolina
# Total Revenue: $18,666.48
#
# Year: 2025
# Month: April
# Territory: Colorado
# Total Revenue: $168,853.86
#
# Year: 2025
# Month: April
# Territory: South Carolina
# Total Revenue: $19,849.82
#
# Year: 2025
# Month: August
# Territory: Colorado
# Total Revenue: $209,591.63
#
# Year: 2025
# Month: August
# Territory: South Carolina
# Total Revenue: $34,374.68
#
# Year: 2025
# Month: December
# Territory: Colorado
# Total Revenue: $208,271.75
#
# Year: 2025
# Month: December
# Territory: South Carolina
# Total Revenue: $22,506.96
#
# Year: 2025
# Month: February
# Territory: Colorado
# Total Revenue: $165,726.20
#
# Year: 2025
# Month: February
# Territory: South Carolina
# Total Revenue: $16,483.87
#
# Year: 2025
# Month: January
# Territory: Colorado
# Total Revenue: $181,006.05
#
# Year: 2025
# Month: January
# Territory: South Carolina
# Total Revenue: $20,427.40
#
# Year: 2025
# Month: July
# Territory: Colorado
# Total Revenue: $204,640.58
#
# Year: 2025
# Month: July
# Territory: South Carolina
# Total Revenue: $21,980.16
#
# Year: 2025
# Month: June
# Territory: Colorado
# Total Revenue: $167,246.64
#
# Year: 2025
# Month: June
# Territory: South Carolina
# Total Revenue: $15,465.18
#
# Year: 2025
# Month: March
# Territory: Colorado
# Total Revenue: $183,144.31
#
# Year: 2025
# Month: March
# Territory: South Carolina
# Total Revenue: $19,779.93
#
# Year: 2025
# Month: May
# Territory: Colorado
# Total Revenue: $186,318.66
#
# Year: 2025
# Month: May
# Territory: South Carolina
# Total Revenue: $15,173.90
#
# Year: 2025
# Month: November
# Territory: Colorado
# Total Revenue: $220,240.73
#
# Year: 2025
# Month: November
# Territory: South Carolina
# Total Revenue: $18,497.16
#
# Year: 2025
# Month: October
# Territory: Colorado
# Total Revenue: $330,762.82
#
# Year: 2025
# Month: October
# Territory: South Carolina
# Total Revenue: $27,491.79
#
# Year: 2025
# Month: September
# Territory: Colorado
# Total Revenue: $196,114.94
#
# Year: 2025
# Month: September
# Territory: South Carolina
# Total Revenue: $16,497.17

# %% [markdown]
# #### Monthly Territory Analysis By Year
# The revenue analysis shows that Colorado consistently generated significantly higher sales revenue than South Carolina from 2022–2025, making it the company’s strongest-performing territory.
#
# Both territories experienced steady year-over-year growth, with the highest sales occurring during 2025, indicating expanding business performance and increasing customer demand.

# %% [markdown]
# #### Question 3
# ##### How would you rank the sales performance of each store in each sales territory? Which are the
# ##### top-performing stores?

# %% [markdown]
# #### Step 1 Identify tables needed to answer the question.

# %%
# use tableinfo to find information about tables

data_info.tableinfo()
# Out:
# Customers Info
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 1 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   cust_id|date|time|name|email|phone|sms-opt-out   521 non-null    str
# dtypes: str(1)
# memory usage: 4.2 KB
#
# Product Categories Info
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB
#
# Products Info
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB
#
# Store Details Info
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB
#
# Stores Sales Info
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %% [markdown]
# ### Step 2 Merge Dataframes(tables), Modify Dataframe, Filter by Territories, Rank Outputs from Greatest to Least

# %%
#________ Notes _________________________________________________________________________________________

# Tables needed to answer the question are storedetails and storesales
# Just like before 
# Im going to resuse code I already scripted for the sake of time
# Merge dataframes storedetails and storesales using pd.merge
# Filter for rows that have colorado or south carolina in the state column using []
# group by by the state, store id and the store location column
# sort from best performing to the least performing using the sort values dataframe method
# the default for sort values is least to greatest so you have to make the argument false to reverse the order
# ascending = false
# When ranking the stores by highest grossing you need to use the enumerate function 
# This ranks return values in the for loop
# loop reads as follows: for every loop return state, state id, city, revenue, and store rank 
# Then print values using an f string that includes a new line(\n) for each value 
# Then assign the method to the class
# Then call the method using an object


#___________________________________________________________________________________________________________

def store_sales_ranking_east_south_region(self):

# Merge dataframes
    
    self.table_merge = pd.merge(
        self.storedetails,
        self.storesales,
        on="Store ID")

# Filter assigned territories
    
    self.filter_merge = self.table_merge[
        (self.table_merge["State"] == "Colorado") |
        (self.table_merge["State"] == "South Carolina")]

# Group by Store, Location, and State
    
    self.grouped_merge = self.filter_merge.groupby(
        ["State", "Store ID", "Store Location"]
    )["Sale Amount"].sum()

# Sort from greatest to least
    
    self.sorted_merge = self.grouped_merge.sort_values(
        ascending=False)

    print("\n── Store Sales Performance Ranking ─────────────────────")

# Rank stores
    
    for rank, ((state, store_id, city), revenue) in enumerate(
        self.sorted_merge.items(),
        start=1):

        print(
            f"\nRank #{rank}"
            f"\nTerritory: {state}"
            f"\nStore ID: {store_id}"
            f"\nCity: {city}"
            f"\nTotal Revenue: ${revenue:,.2f}")


# Assign method to class

EmpAnalysis.store_sales_ranking_east_south_region = store_sales_ranking_east_south_region

# Run analysis

data_info.store_sales_ranking_east_south_region()
# Out:
# ── Store Sales Performance Ranking ─────────────────────
#
# Rank #1
# Territory: Colorado
# Store ID: 705
# City: Denver
# Total Revenue: $917,471.53
#
# Rank #2
# Territory: Colorado
# Store ID: 709
# City: Greeley
# Total Revenue: $640,368.11
#
# Rank #3
# Territory: Colorado
# Store ID: 706
# City: Englewood
# Total Revenue: $344,647.48
#
# Rank #4
# Territory: Colorado
# Store ID: 710
# City: Lafayette
# Total Revenue: $337,169.61
#
# Rank #5
# Territory: South Carolina
# Store ID: 853
# City: Greenville
# Total Revenue: $337,002.00
#
# Rank #6
# Territory: Colorado
# Store ID: 703
# City: Boulder
# Total Revenue: $321,197.88
#
# Rank #7
# Territory: Colorado
# Store ID: 716
# City: Sedalia
# Total Revenue: $319,776.13
#
# Rank #8
# Territory: Colorado
# Store ID: 701
# City: Aurora
# Total Revenue: $317,198.67
#
# Rank #9
# Territory: South Carolina
# Store ID: 852
# City: Charleston
# Total Revenue: $311,810.56
#
# Rank #10
# Territory: Colorado
# Store ID: 708
# City: Grand Junction
# Total Revenue: $306,834.49
#
# Rank #11
# Territory: Colorado
# Store ID: 707
# City: Fort Collins
# Total Revenue: $302,660.34
#
# Rank #12
# Territory: Colorado
# Store ID: 704
# City: Castle Rock
# Total Revenue: $299,122.02
#
# Rank #13
# Territory: Colorado
# Store ID: 714
# City: New Castle
# Total Revenue: $298,504.41
#
# Rank #14
# Territory: Colorado
# Store ID: 712
# City: Loveland
# Total Revenue: $297,702.56
#
# Rank #15
# Territory: Colorado
# Store ID: 717
# City: Thornton
# Total Revenue: $294,530.76
#
# Rank #16
# Territory: Colorado
# Store ID: 711
# City: Littleton
# Total Revenue: $289,514.27
#
# Rank #17
# Territory: Colorado
# Store ID: 713
# City: Milliken
# Total Revenue: $284,586.13
#
# Rank #18
# Territory: Colorado
# Store ID: 702
# City: Berthoud
# Total Revenue: $281,182.34
#
# Rank #19
# Territory: Colorado
# Store ID: 718
# City: Wheat Ridge
# Total Revenue: $280,896.55
#
# Rank #20
# Territory: Colorado
# Store ID: 715
# City: Parker
# Total Revenue: $279,268.94

# %% [markdown]
# #### Ranking Summary
# Colorado was the strongest overall sales territory, accounting for 18 of the top 20 ranked stores in total revenue performance. Store 705 in Denver was the highest-performing location, generating more than 917,000 in total revenue during the reporting period.
#
# The lowest-performing store in the rankings was Store 715 in Parker, Colorado, with approximately 279,000 in total revenue.

# %% [markdown]
# ### Question 4
# #### Comparing the customer ID from the customer list data with the rewards ID from the sales data,
# #### who were the top customers in each sales territory?

# %% [markdown]
# ### Step 1 Identify tables needed

# %%
# use tableinfo to find information about tables

data_info.tableinfo()
# Out:
# Customers Info
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 1 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   cust_id|date|time|name|email|phone|sms-opt-out   521 non-null    str
# dtypes: str(1)
# memory usage: 4.2 KB
#
# Product Categories Info
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB
#
# Products Info
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB
#
# Store Details Info
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB
#
# Stores Sales Info
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %% [markdown]
# #### Step 2  Merge Dataframes(tables), Modify Dataframe, Filter by Territories, Rank Customers

# %%
#________ Notes ________________________________________________________________________________________________

# The customer_list file was imported incorrectly as one column.
# The customer_list file uses "|" instead of commas as the delimiter.
# Split the single column into multiple columns using .str.split().
# Rename the separated columns.
# Convert cust_id and RewardsID into float data types.
# Merge storesales and customer_list using RewardsID and cust_id.
# Merge customer_sales_merge with storedetails using Store ID.
# Group the data by State, cust_id, and name.
# Use .sum() to calculate the total sales revenue for each customer.
# Sort the grouped data from highest to lowest using .sort_values().
# Convert the grouped results into a dataframe using .reset_index().
# Use .head(5) to display the top 5 customers in each territory.
# Use enumerate() and .itertuples() to print formatted results.

#_______________________________________________________________________________________________________________



def top_customers_by_territory(self):

    
# Split customer_list only if needed
    

    if len(self.customer_list.columns) == 1:

        self.customer_list = self.customer_list[
            self.customer_list.columns[0]
        ].str.split("|", expand=True)
        
# Rename columns
        

        self.customer_list.columns = [
            "cust_id",
            "date",
            "time",
            "name",
            "email",
            "phone",
            "sms_opt_out"]

    
# Convert IDs to same datatype
    

    self.customer_list["cust_id"] = (
        self.customer_list["cust_id"].astype(float))

    self.storesales["RewardsID"] = (
        self.storesales["RewardsID"].astype(float))

    
# Merge customer list with sales data
    

    self.customer_sales_merge = pd.merge(
        self.storesales,
        self.customer_list,
        left_on="RewardsID",
        right_on="cust_id",
        how="inner")

    
# Merge with store details
    

    self.customer_territory_merge = pd.merge(
        self.customer_sales_merge,
        self.storedetails,
        on="Store ID",
        how="inner")

    
# Group by territory and customer


    self.top_customers = self.customer_territory_merge.groupby(
        ["State", "cust_id", "name"]
    )["Sale Amount"].sum()

   
# Sort highest revenue customers first
    

    self.sorted_top_customers = self.top_customers.sort_values(
        ascending=False)

    
# Convert grouped results into dataframe
    

    self.top_customers_df = (
        self.sorted_top_customers.reset_index())

    
# Print top 5 customers by territory
    

    print("\n── Top 5 Customers by Sales Territory ───────────────\n")

    for territory in ["Colorado", "South Carolina"]:

        print(f"\n========== {territory} ==========\n")

        self.territory_top5 = self.top_customers_df[
            self.top_customers_df["State"] == territory
        ].head(5)

        for rank, row in enumerate(
            self.territory_top5.itertuples(),
            start=1):

            print(f"""
                Rank #{rank}

                Territory: {row.State}

                Customer ID: {row.cust_id}

                Customer Name: {row.name}

                Total Revenue: ${row._4:,.2f}""")



# Add Method to Class


EmpAnalysis.top_customers_by_territory = top_customers_by_territory



# Run Method


data_info.top_customers_by_territory()
# Out:
# ── Top 5 Customers by Sales Territory ───────────────
#
#
# ========== Colorado ==========
#
#
# Rank #1
#
# Territory: Colorado
#
# Customer ID: 245.0
#
# Customer Name: Gloria Mendoza
#
# Total Revenue: $7,855.66
#
#
# Rank #2
#
# Territory: Colorado
#
# Customer ID: 375.0
#
# Customer Name: C.J. Cregg
#
# Total Revenue: $5,006.57
#
#
# Rank #3
#
# Territory: Colorado
#
# Customer ID: 380.0
#
# Customer Name: Abbey Bartlet
#
# Total Revenue: $4,605.19
#
#
# Rank #4
#
# Territory: Colorado
#
# Customer ID: 242.0
#
# Customer Name: Lorna Morello
#
# Total Revenue: $4,381.15
#
#
# Rank #5
#
# Territory: Colorado
#
# Customer ID: 279.0
#
# Customer Name: Adrian Veidt
#
# Total Revenue: $4,365.77
#
#
# ========== South Carolina ==========
#
#
# Rank #1
#
# Territory: South Carolina
#
# Customer ID: 340.0
#
# Customer Name: Jin Kwon
#
# Total Revenue: $1,786.05
#
#
# Rank #2
#
# Territory: South Carolina
#
# Customer ID: 404.0
#
# Customer Name: Roman Roy
#
# Total Revenue: $1,778.84
#
#
# Rank #3
#
# Territory: South Carolina
#
# Customer ID: 213.0
#
# Customer Name: Jazz
#
# Total Revenue: $1,763.70
#
#
# Rank #4
#
# Territory: South Carolina
#
# Customer ID: 74.0
#
# Customer Name: Ben Chang
#
# Total Revenue: $1,566.60
#
#
# Rank #5
#
# Territory: South Carolina
#
# Customer ID: 280.0
#
# Customer Name: Cal Abar
#
# Total Revenue: $1,396.50

# %% [markdown]
# #### Top Customer Per Territory Summary
# Colorado was the strongest-performing territory overall, with Gloria Mendoza generating the highest customer revenue at approximately 7,855.66, while Adrian Veidt was the lowest-ranked top-five customer in the territory with about 4,365.77 in sales.
#
# In South Carolina, Jin Kwon was the highest-performing customer with approximately 1,786.05 in revenue, while Cal Abar ranked lowest among the top five customers with about 1,396.50 in sales. Overall, Colorado significantly outperformed South Carolina in total customer revenue, indicating a stronger concentration of high-value customers within the territory.

# %% [markdown]
# ### Top Customer Sales Chart

# %%
#________ Chart Notes ___________________________________________________________________________________________

# Import matplotlib.pyplot as plt to create charts and visualizations.
# Use a for loop to create separate charts for Colorado and South Carolina.
# Filter the dataframe by State so each chart only displays one territory.
# Use plt.bar() to create a bar chart for customer revenue.
# The x-axis displays customer names.
# The y-axis displays total revenue generated by each customer.
# figsize controls the size of the chart window.
# plt.title(), plt.xlabel(), and plt.ylabel() add chart labels.
# plt.xticks(rotation=45) rotates customer names for easier reading.
# plt.tight_layout() prevents labels from overlapping.
# plt.show() displays the completed chart.

#_______________________________________________________________________________________________________________


#________ Results Notes _________________________________________________________________________________________

# The charts display the top 5 customers with the highest
# total sales revenue in Colorado and South Carolina.

# Colorado customers generated significantly higher revenue
# totals compared to South Carolina customers, indicating
# stronger customer spending within the Colorado territory.

# Gloria Mendoza was the highest-performing customer overall,
# generating more than $7,800 in total revenue for Colorado.

# The Colorado territory showed a larger gap between the
# highest-performing and lowest-performing top customers,
# suggesting a stronger concentration of high-value customers.

# South Carolina generated lower customer revenue totals,
# but the top customers still contributed consistently to
# territory sales performance.

# The charts help identify the company’s most valuable
# customers and may support future customer retention,
# loyalty programs, and targeted marketing strategies.

# Customers with consistently high purchase activity may
# represent long-term business opportunities and priority
# customer relationships.

#_______________________________________________________________________________________________________________




# Create chart for each territory

for territory in ["Colorado", "South Carolina"]:

    # Filter territory data

    territory_chart = data_info.top_customers_df[
        data_info.top_customers_df["State"] == territory
    ].head(5)


    # Create bar chart

    mp.figure(figsize=(10, 6))

    mp.bar(
        territory_chart["name"],
        territory_chart["Sale Amount"]
    )


    # Chart labels

    mp.title(
        f"Top 5 Customers by Revenue - {territory}"
    )

    mp.xlabel("Customer Name")

    mp.ylabel("Total Revenue")

    mp.xticks(rotation=45)

    mp.tight_layout()

    mp.show()

# %% [markdown]
# ### Question 5
# #### What is the number of transactions per month by product category in each assigned territory? What is total sales revenue per month by category?   What might this tell you about the most  popular products, and where could there be opportunity for growth?

# %% [markdown]
# #### Step 1 Identify what tables are needed to answer this question.

# %%
# use tableinfo to find information about tables

data_info.tableinfo()
# Out:
# Customers Info
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      521 non-null    float64
#  1   date         521 non-null    str
#  2   time         521 non-null    str
#  3   name         521 non-null    str
#  4   email        521 non-null    str
#  5   phone        520 non-null    str
#  6   sms_opt_out  520 non-null    str
# dtypes: float64(1), str(6)
# memory usage: 28.6 KB
#
# Product Categories Info
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB
#
# Products Info
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB
#
# Store Details Info
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB
#
# Stores Sales Info
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %%
#________ Notes ________________________________________________________________________________________________

# The tables used for this analysis are storesales, products,
# productcategories, and storedetails.
# storesales contains transaction dates, product numbers, and sale amounts.
# products contains the product names and category IDs.
# productcategories contains category and subcategory information.
# storedetails contains territory and store information.
# Convert Transaction Date into datetime format using pd.to_datetime().
# Extract the Month and Year using dt.month_name() and dt.year.
# Merge storesales and products using Prod Num.
# Merge products and productcategories using CategoryID and SubcategoryID.
# Merge the combined dataframe with storedetails using Store ID.
# Filter the data for Colorado and South Carolina territories only.
# Group the data by Year, Month, State, and Category.
# Use .count() to calculate the number of transactions per category.
# Use .sum() to calculate total sales revenue by category.
# Sort the grouped data using .sort_index().
# Print formatted transaction and revenue results using for loops.

#_______________________________________________________________________________________________________________






def monthly_category_analysis(self):

   
# Convert Transaction Date to datetime
    

    self.storesales["Transaction Date"] = pd.to_datetime(
        self.storesales["Transaction Date"])

    
# Create Month and Year columns
    

    self.storesales["Month"] = (
        self.storesales["Transaction Date"].dt.month_name())

    self.storesales["Year"] = (
        self.storesales["Transaction Date"].dt.year)

    
# Merge storesales with products
    

    self.sales_products_merge = pd.merge(
        self.storesales,
        self.products,
        on="Prod Num",
        how="inner")

    
# Merge with productcategories
    

    self.sales_category_merge = pd.merge(
        self.sales_products_merge,
        self.productcategories,
        on=["CategoryID", "SubcategoryID"],
        how="inner")

    
# Merge with storedetails
    

    self.final_category_merge = pd.merge(
        self.sales_category_merge,
        self.storedetails,
        on="Store ID",
        how="inner")

    
# Filter assigned territories
    

    self.filtered_territories = self.final_category_merge[
        (self.final_category_merge["State"] == "Colorado") |
        (self.final_category_merge["State"] == "South Carolina")]

    
# Group transaction counts
    

    self.transaction_summary = self.filtered_territories.groupby(
        ["Year", "Month", "State", "Category"]
    )["Prod Num"].count()

    
# Group revenue totals
    

    self.revenue_summary = self.filtered_territories.groupby(
        ["Year", "Month", "State", "Category"]
    )["Sale Amount"].sum()

    
# Sort grouped data
    

    self.transaction_summary = (
        self.transaction_summary.sort_index())

    self.revenue_summary = (
        self.revenue_summary.sort_index())

    
# Print transaction results
    

    print("\n── Monthly Transactions by Product Category ───────────────\n")

    for (year, month, state, category), transactions in (
        self.transaction_summary.items()):

        print(f"""
            Year: {year}

            Month: {month}

            Territory: {state}

            Category: {category}

            Transactions: {transactions}""")

    
# Print revenue results
    

    print("\n── Monthly Revenue by Product Category ───────────────\n")

    for (year, month, state, category), revenue in (
        self.revenue_summary.items()):

        print(f"""
            Year: {year}

            Month: {month}

            Territory: {state}

            Category: {category}

            Total Revenue: ${revenue:,.2f}""")



# Add Method to Class


EmpAnalysis.monthly_category_analysis = monthly_category_analysis



# Run Method


data_info.monthly_category_analysis()
# Out:
# ── Monthly Transactions by Product Category ───────────────
#
#
# Year: 2022
#
# Month: April
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 100
#
#
# Year: 2022
#
# Month: April
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 77
#
#
# Year: 2022
#
# Month: April
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 42
#
#
# Year: 2022
#
# Month: April
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 113
#
#
# Year: 2022
#
# Month: April
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 136
#
#
# Year: 2022
#
# Month: April
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 112
#
#
# Year: 2022
#
# Month: April
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: April
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: April
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2022
#
# Month: April
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 13
#
#
# Year: 2022
#
# Month: April
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: April
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2022
#
# Month: August
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 114
#
#
# Year: 2022
#
# Month: August
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 102
#
#
# Year: 2022
#
# Month: August
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 36
#
#
# Year: 2022
#
# Month: August
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 114
#
#
# Year: 2022
#
# Month: August
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 125
#
#
# Year: 2022
#
# Month: August
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 102
#
#
# Year: 2022
#
# Month: August
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 10
#
#
# Year: 2022
#
# Month: August
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 12
#
#
# Year: 2022
#
# Month: August
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2022
#
# Month: August
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: August
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 11
#
#
# Year: 2022
#
# Month: August
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 17
#
#
# Year: 2022
#
# Month: December
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 111
#
#
# Year: 2022
#
# Month: December
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 90
#
#
# Year: 2022
#
# Month: December
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 62
#
#
# Year: 2022
#
# Month: December
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 121
#
#
# Year: 2022
#
# Month: December
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 110
#
#
# Year: 2022
#
# Month: December
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 97
#
#
# Year: 2022
#
# Month: December
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 7
#
#
# Year: 2022
#
# Month: December
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 14
#
#
# Year: 2022
#
# Month: December
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2022
#
# Month: December
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 10
#
#
# Year: 2022
#
# Month: December
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 7
#
#
# Year: 2022
#
# Month: December
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 8
#
#
# Year: 2022
#
# Month: February
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 80
#
#
# Year: 2022
#
# Month: February
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 117
#
#
# Year: 2022
#
# Month: February
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 43
#
#
# Year: 2022
#
# Month: February
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 106
#
#
# Year: 2022
#
# Month: February
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 141
#
#
# Year: 2022
#
# Month: February
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 96
#
#
# Year: 2022
#
# Month: February
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 13
#
#
# Year: 2022
#
# Month: February
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 10
#
#
# Year: 2022
#
# Month: February
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 6
#
#
# Year: 2022
#
# Month: February
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 11
#
#
# Year: 2022
#
# Month: February
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 14
#
#
# Year: 2022
#
# Month: February
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 5
#
#
# Year: 2022
#
# Month: January
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 108
#
#
# Year: 2022
#
# Month: January
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 98
#
#
# Year: 2022
#
# Month: January
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 43
#
#
# Year: 2022
#
# Month: January
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 112
#
#
# Year: 2022
#
# Month: January
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 126
#
#
# Year: 2022
#
# Month: January
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 106
#
#
# Year: 2022
#
# Month: January
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 12
#
#
# Year: 2022
#
# Month: January
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 8
#
#
# Year: 2022
#
# Month: January
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2022
#
# Month: January
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 7
#
#
# Year: 2022
#
# Month: January
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 13
#
#
# Year: 2022
#
# Month: January
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: July
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 96
#
#
# Year: 2022
#
# Month: July
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 116
#
#
# Year: 2022
#
# Month: July
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 41
#
#
# Year: 2022
#
# Month: July
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 100
#
#
# Year: 2022
#
# Month: July
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 151
#
#
# Year: 2022
#
# Month: July
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 106
#
#
# Year: 2022
#
# Month: July
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 11
#
#
# Year: 2022
#
# Month: July
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 12
#
#
# Year: 2022
#
# Month: July
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 6
#
#
# Year: 2022
#
# Month: July
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 10
#
#
# Year: 2022
#
# Month: July
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 17
#
#
# Year: 2022
#
# Month: July
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 15
#
#
# Year: 2022
#
# Month: June
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 95
#
#
# Year: 2022
#
# Month: June
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 74
#
#
# Year: 2022
#
# Month: June
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 47
#
#
# Year: 2022
#
# Month: June
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 117
#
#
# Year: 2022
#
# Month: June
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 127
#
#
# Year: 2022
#
# Month: June
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 95
#
#
# Year: 2022
#
# Month: June
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 14
#
#
# Year: 2022
#
# Month: June
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 5
#
#
# Year: 2022
#
# Month: June
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 2
#
#
# Year: 2022
#
# Month: June
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 8
#
#
# Year: 2022
#
# Month: June
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 11
#
#
# Year: 2022
#
# Month: June
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 6
#
#
# Year: 2022
#
# Month: March
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 99
#
#
# Year: 2022
#
# Month: March
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 100
#
#
# Year: 2022
#
# Month: March
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 47
#
#
# Year: 2022
#
# Month: March
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 104
#
#
# Year: 2022
#
# Month: March
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 128
#
#
# Year: 2022
#
# Month: March
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 85
#
#
# Year: 2022
#
# Month: March
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: March
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 17
#
#
# Year: 2022
#
# Month: March
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 1
#
#
# Year: 2022
#
# Month: March
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 7
#
#
# Year: 2022
#
# Month: March
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 15
#
#
# Year: 2022
#
# Month: March
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 10
#
#
# Year: 2022
#
# Month: May
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 95
#
#
# Year: 2022
#
# Month: May
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 121
#
#
# Year: 2022
#
# Month: May
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 29
#
#
# Year: 2022
#
# Month: May
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 109
#
#
# Year: 2022
#
# Month: May
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 146
#
#
# Year: 2022
#
# Month: May
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 127
#
#
# Year: 2022
#
# Month: May
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: May
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 4
#
#
# Year: 2022
#
# Month: May
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 6
#
#
# Year: 2022
#
# Month: May
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 14
#
#
# Year: 2022
#
# Month: May
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 6
#
#
# Year: 2022
#
# Month: May
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: November
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 88
#
#
# Year: 2022
#
# Month: November
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 88
#
#
# Year: 2022
#
# Month: November
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 51
#
#
# Year: 2022
#
# Month: November
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 86
#
#
# Year: 2022
#
# Month: November
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 108
#
#
# Year: 2022
#
# Month: November
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 113
#
#
# Year: 2022
#
# Month: November
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 10
#
#
# Year: 2022
#
# Month: November
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 12
#
#
# Year: 2022
#
# Month: November
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2022
#
# Month: November
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 7
#
#
# Year: 2022
#
# Month: November
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 8
#
#
# Year: 2022
#
# Month: November
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 16
#
#
# Year: 2022
#
# Month: October
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 97
#
#
# Year: 2022
#
# Month: October
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 120
#
#
# Year: 2022
#
# Month: October
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 68
#
#
# Year: 2022
#
# Month: October
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 110
#
#
# Year: 2022
#
# Month: October
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 116
#
#
# Year: 2022
#
# Month: October
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 119
#
#
# Year: 2022
#
# Month: October
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 12
#
#
# Year: 2022
#
# Month: October
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: October
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 2
#
#
# Year: 2022
#
# Month: October
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 14
#
#
# Year: 2022
#
# Month: October
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 17
#
#
# Year: 2022
#
# Month: October
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 6
#
#
# Year: 2022
#
# Month: September
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 94
#
#
# Year: 2022
#
# Month: September
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 126
#
#
# Year: 2022
#
# Month: September
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 55
#
#
# Year: 2022
#
# Month: September
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 108
#
#
# Year: 2022
#
# Month: September
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 120
#
#
# Year: 2022
#
# Month: September
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 106
#
#
# Year: 2022
#
# Month: September
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 9
#
#
# Year: 2022
#
# Month: September
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 7
#
#
# Year: 2022
#
# Month: September
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2022
#
# Month: September
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 16
#
#
# Year: 2022
#
# Month: September
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 13
#
#
# Year: 2022
#
# Month: September
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2023
#
# Month: April
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 185
#
#
# Year: 2023
#
# Month: April
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 180
#
#
# Year: 2023
#
# Month: April
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 80
#
#
# Year: 2023
#
# Month: April
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 208
#
#
# Year: 2023
#
# Month: April
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 203
#
#
# Year: 2023
#
# Month: April
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 123
#
#
# Year: 2023
#
# Month: April
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 19
#
#
# Year: 2023
#
# Month: April
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 16
#
#
# Year: 2023
#
# Month: April
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 7
#
#
# Year: 2023
#
# Month: April
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 19
#
#
# Year: 2023
#
# Month: April
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 18
#
#
# Year: 2023
#
# Month: April
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 10
#
#
# Year: 2023
#
# Month: August
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 179
#
#
# Year: 2023
#
# Month: August
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 174
#
#
# Year: 2023
#
# Month: August
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 69
#
#
# Year: 2023
#
# Month: August
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 186
#
#
# Year: 2023
#
# Month: August
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 193
#
#
# Year: 2023
#
# Month: August
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 165
#
#
# Year: 2023
#
# Month: August
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 23
#
#
# Year: 2023
#
# Month: August
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 13
#
#
# Year: 2023
#
# Month: August
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 8
#
#
# Year: 2023
#
# Month: August
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 13
#
#
# Year: 2023
#
# Month: August
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 25
#
#
# Year: 2023
#
# Month: August
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2023
#
# Month: December
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 174
#
#
# Year: 2023
#
# Month: December
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 154
#
#
# Year: 2023
#
# Month: December
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 66
#
#
# Year: 2023
#
# Month: December
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 186
#
#
# Year: 2023
#
# Month: December
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 187
#
#
# Year: 2023
#
# Month: December
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 161
#
#
# Year: 2023
#
# Month: December
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 15
#
#
# Year: 2023
#
# Month: December
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 24
#
#
# Year: 2023
#
# Month: December
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 5
#
#
# Year: 2023
#
# Month: December
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 19
#
#
# Year: 2023
#
# Month: December
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 21
#
#
# Year: 2023
#
# Month: December
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 12
#
#
# Year: 2023
#
# Month: February
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 181
#
#
# Year: 2023
#
# Month: February
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 158
#
#
# Year: 2023
#
# Month: February
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 48
#
#
# Year: 2023
#
# Month: February
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 179
#
#
# Year: 2023
#
# Month: February
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 207
#
#
# Year: 2023
#
# Month: February
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 111
#
#
# Year: 2023
#
# Month: February
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 19
#
#
# Year: 2023
#
# Month: February
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 17
#
#
# Year: 2023
#
# Month: February
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 5
#
#
# Year: 2023
#
# Month: February
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 15
#
#
# Year: 2023
#
# Month: February
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 21
#
#
# Year: 2023
#
# Month: February
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 4
#
#
# Year: 2023
#
# Month: January
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 172
#
#
# Year: 2023
#
# Month: January
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 152
#
#
# Year: 2023
#
# Month: January
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 68
#
#
# Year: 2023
#
# Month: January
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 178
#
#
# Year: 2023
#
# Month: January
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 203
#
#
# Year: 2023
#
# Month: January
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 105
#
#
# Year: 2023
#
# Month: January
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 20
#
#
# Year: 2023
#
# Month: January
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 21
#
#
# Year: 2023
#
# Month: January
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 10
#
#
# Year: 2023
#
# Month: January
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 19
#
#
# Year: 2023
#
# Month: January
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 20
#
#
# Year: 2023
#
# Month: January
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 11
#
#
# Year: 2023
#
# Month: July
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 194
#
#
# Year: 2023
#
# Month: July
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 212
#
#
# Year: 2023
#
# Month: July
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 64
#
#
# Year: 2023
#
# Month: July
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 166
#
#
# Year: 2023
#
# Month: July
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 188
#
#
# Year: 2023
#
# Month: July
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 154
#
#
# Year: 2023
#
# Month: July
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 17
#
#
# Year: 2023
#
# Month: July
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 24
#
#
# Year: 2023
#
# Month: July
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 10
#
#
# Year: 2023
#
# Month: July
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 9
#
#
# Year: 2023
#
# Month: July
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 21
#
#
# Year: 2023
#
# Month: July
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 10
#
#
# Year: 2023
#
# Month: June
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 162
#
#
# Year: 2023
#
# Month: June
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 138
#
#
# Year: 2023
#
# Month: June
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 78
#
#
# Year: 2023
#
# Month: June
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 167
#
#
# Year: 2023
#
# Month: June
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 179
#
#
# Year: 2023
#
# Month: June
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 128
#
#
# Year: 2023
#
# Month: June
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 15
#
#
# Year: 2023
#
# Month: June
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 17
#
#
# Year: 2023
#
# Month: June
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 7
#
#
# Year: 2023
#
# Month: June
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 17
#
#
# Year: 2023
#
# Month: June
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 17
#
#
# Year: 2023
#
# Month: June
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 16
#
#
# Year: 2023
#
# Month: March
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 153
#
#
# Year: 2023
#
# Month: March
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 161
#
#
# Year: 2023
#
# Month: March
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 62
#
#
# Year: 2023
#
# Month: March
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 183
#
#
# Year: 2023
#
# Month: March
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 183
#
#
# Year: 2023
#
# Month: March
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 114
#
#
# Year: 2023
#
# Month: March
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 8
#
#
# Year: 2023
#
# Month: March
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 19
#
#
# Year: 2023
#
# Month: March
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 8
#
#
# Year: 2023
#
# Month: March
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 13
#
#
# Year: 2023
#
# Month: March
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 20
#
#
# Year: 2023
#
# Month: March
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 9
#
#
# Year: 2023
#
# Month: May
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 165
#
#
# Year: 2023
#
# Month: May
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 173
#
#
# Year: 2023
#
# Month: May
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 72
#
#
# Year: 2023
#
# Month: May
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 165
#
#
# Year: 2023
#
# Month: May
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 196
#
#
# Year: 2023
#
# Month: May
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 113
#
#
# Year: 2023
#
# Month: May
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 18
#
#
# Year: 2023
#
# Month: May
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 12
#
#
# Year: 2023
#
# Month: May
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 6
#
#
# Year: 2023
#
# Month: May
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 14
#
#
# Year: 2023
#
# Month: May
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 19
#
#
# Year: 2023
#
# Month: May
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 15
#
#
# Year: 2023
#
# Month: November
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 159
#
#
# Year: 2023
#
# Month: November
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 162
#
#
# Year: 2023
#
# Month: November
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 81
#
#
# Year: 2023
#
# Month: November
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 174
#
#
# Year: 2023
#
# Month: November
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 191
#
#
# Year: 2023
#
# Month: November
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 154
#
#
# Year: 2023
#
# Month: November
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 18
#
#
# Year: 2023
#
# Month: November
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 15
#
#
# Year: 2023
#
# Month: November
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 7
#
#
# Year: 2023
#
# Month: November
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 21
#
#
# Year: 2023
#
# Month: November
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 15
#
#
# Year: 2023
#
# Month: November
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2023
#
# Month: October
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 159
#
#
# Year: 2023
#
# Month: October
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 146
#
#
# Year: 2023
#
# Month: October
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 64
#
#
# Year: 2023
#
# Month: October
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 172
#
#
# Year: 2023
#
# Month: October
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 181
#
#
# Year: 2023
#
# Month: October
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 142
#
#
# Year: 2023
#
# Month: October
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 17
#
#
# Year: 2023
#
# Month: October
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 12
#
#
# Year: 2023
#
# Month: October
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 3
#
#
# Year: 2023
#
# Month: October
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 21
#
#
# Year: 2023
#
# Month: October
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 22
#
#
# Year: 2023
#
# Month: October
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 20
#
#
# Year: 2023
#
# Month: September
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 147
#
#
# Year: 2023
#
# Month: September
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 140
#
#
# Year: 2023
#
# Month: September
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 60
#
#
# Year: 2023
#
# Month: September
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 154
#
#
# Year: 2023
#
# Month: September
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 197
#
#
# Year: 2023
#
# Month: September
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 175
#
#
# Year: 2023
#
# Month: September
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 12
#
#
# Year: 2023
#
# Month: September
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 21
#
#
# Year: 2023
#
# Month: September
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2023
#
# Month: September
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 13
#
#
# Year: 2023
#
# Month: September
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 12
#
#
# Year: 2023
#
# Month: September
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 15
#
#
# Year: 2024
#
# Month: April
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 158
#
#
# Year: 2024
#
# Month: April
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 165
#
#
# Year: 2024
#
# Month: April
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 72
#
#
# Year: 2024
#
# Month: April
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 158
#
#
# Year: 2024
#
# Month: April
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 190
#
#
# Year: 2024
#
# Month: April
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 110
#
#
# Year: 2024
#
# Month: April
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: April
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 12
#
#
# Year: 2024
#
# Month: April
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 5
#
#
# Year: 2024
#
# Month: April
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 12
#
#
# Year: 2024
#
# Month: April
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 19
#
#
# Year: 2024
#
# Month: April
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 15
#
#
# Year: 2024
#
# Month: August
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 151
#
#
# Year: 2024
#
# Month: August
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 142
#
#
# Year: 2024
#
# Month: August
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 61
#
#
# Year: 2024
#
# Month: August
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 161
#
#
# Year: 2024
#
# Month: August
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 204
#
#
# Year: 2024
#
# Month: August
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 177
#
#
# Year: 2024
#
# Month: August
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 12
#
#
# Year: 2024
#
# Month: August
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 22
#
#
# Year: 2024
#
# Month: August
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 4
#
#
# Year: 2024
#
# Month: August
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 15
#
#
# Year: 2024
#
# Month: August
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 12
#
#
# Year: 2024
#
# Month: August
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 15
#
#
# Year: 2024
#
# Month: December
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 172
#
#
# Year: 2024
#
# Month: December
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 152
#
#
# Year: 2024
#
# Month: December
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 68
#
#
# Year: 2024
#
# Month: December
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 178
#
#
# Year: 2024
#
# Month: December
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 203
#
#
# Year: 2024
#
# Month: December
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 105
#
#
# Year: 2024
#
# Month: December
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 20
#
#
# Year: 2024
#
# Month: December
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 21
#
#
# Year: 2024
#
# Month: December
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 10
#
#
# Year: 2024
#
# Month: December
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 19
#
#
# Year: 2024
#
# Month: December
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 20
#
#
# Year: 2024
#
# Month: December
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 11
#
#
# Year: 2024
#
# Month: February
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 140
#
#
# Year: 2024
#
# Month: February
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 141
#
#
# Year: 2024
#
# Month: February
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 57
#
#
# Year: 2024
#
# Month: February
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 170
#
#
# Year: 2024
#
# Month: February
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 169
#
#
# Year: 2024
#
# Month: February
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 110
#
#
# Year: 2024
#
# Month: February
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 8
#
#
# Year: 2024
#
# Month: February
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: February
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 7
#
#
# Year: 2024
#
# Month: February
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 11
#
#
# Year: 2024
#
# Month: February
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 20
#
#
# Year: 2024
#
# Month: February
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 9
#
#
# Year: 2024
#
# Month: January
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 201
#
#
# Year: 2024
#
# Month: January
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 182
#
#
# Year: 2024
#
# Month: January
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 56
#
#
# Year: 2024
#
# Month: January
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 200
#
#
# Year: 2024
#
# Month: January
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 226
#
#
# Year: 2024
#
# Month: January
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 120
#
#
# Year: 2024
#
# Month: January
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 19
#
#
# Year: 2024
#
# Month: January
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: January
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 6
#
#
# Year: 2024
#
# Month: January
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: January
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 24
#
#
# Year: 2024
#
# Month: January
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 4
#
#
# Year: 2024
#
# Month: July
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 179
#
#
# Year: 2024
#
# Month: July
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 174
#
#
# Year: 2024
#
# Month: July
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 69
#
#
# Year: 2024
#
# Month: July
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 186
#
#
# Year: 2024
#
# Month: July
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 193
#
#
# Year: 2024
#
# Month: July
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 165
#
#
# Year: 2024
#
# Month: July
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 23
#
#
# Year: 2024
#
# Month: July
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 13
#
#
# Year: 2024
#
# Month: July
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 8
#
#
# Year: 2024
#
# Month: July
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 13
#
#
# Year: 2024
#
# Month: July
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 25
#
#
# Year: 2024
#
# Month: July
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2024
#
# Month: June
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 191
#
#
# Year: 2024
#
# Month: June
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 206
#
#
# Year: 2024
#
# Month: June
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 61
#
#
# Year: 2024
#
# Month: June
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 161
#
#
# Year: 2024
#
# Month: June
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 181
#
#
# Year: 2024
#
# Month: June
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 150
#
#
# Year: 2024
#
# Month: June
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 17
#
#
# Year: 2024
#
# Month: June
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 23
#
#
# Year: 2024
#
# Month: June
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 10
#
#
# Year: 2024
#
# Month: June
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 9
#
#
# Year: 2024
#
# Month: June
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 20
#
#
# Year: 2024
#
# Month: June
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 9
#
#
# Year: 2024
#
# Month: March
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 192
#
#
# Year: 2024
#
# Month: March
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 188
#
#
# Year: 2024
#
# Month: March
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 80
#
#
# Year: 2024
#
# Month: March
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 215
#
#
# Year: 2024
#
# Month: March
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 209
#
#
# Year: 2024
#
# Month: March
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 126
#
#
# Year: 2024
#
# Month: March
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 19
#
#
# Year: 2024
#
# Month: March
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 16
#
#
# Year: 2024
#
# Month: March
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 8
#
#
# Year: 2024
#
# Month: March
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 21
#
#
# Year: 2024
#
# Month: March
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: March
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 10
#
#
# Year: 2024
#
# Month: May
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 165
#
#
# Year: 2024
#
# Month: May
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 144
#
#
# Year: 2024
#
# Month: May
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 81
#
#
# Year: 2024
#
# Month: May
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 172
#
#
# Year: 2024
#
# Month: May
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 186
#
#
# Year: 2024
#
# Month: May
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 132
#
#
# Year: 2024
#
# Month: May
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 15
#
#
# Year: 2024
#
# Month: May
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: May
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 7
#
#
# Year: 2024
#
# Month: May
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 17
#
#
# Year: 2024
#
# Month: May
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: May
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 17
#
#
# Year: 2024
#
# Month: November
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 168
#
#
# Year: 2024
#
# Month: November
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 151
#
#
# Year: 2024
#
# Month: November
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 65
#
#
# Year: 2024
#
# Month: November
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 182
#
#
# Year: 2024
#
# Month: November
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 180
#
#
# Year: 2024
#
# Month: November
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 156
#
#
# Year: 2024
#
# Month: November
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 15
#
#
# Year: 2024
#
# Month: November
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 24
#
#
# Year: 2024
#
# Month: November
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 5
#
#
# Year: 2024
#
# Month: November
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 19
#
#
# Year: 2024
#
# Month: November
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 20
#
#
# Year: 2024
#
# Month: November
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 12
#
#
# Year: 2024
#
# Month: October
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 165
#
#
# Year: 2024
#
# Month: October
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 165
#
#
# Year: 2024
#
# Month: October
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 82
#
#
# Year: 2024
#
# Month: October
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 178
#
#
# Year: 2024
#
# Month: October
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 198
#
#
# Year: 2024
#
# Month: October
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 159
#
#
# Year: 2024
#
# Month: October
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 18
#
#
# Year: 2024
#
# Month: October
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 15
#
#
# Year: 2024
#
# Month: October
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 7
#
#
# Year: 2024
#
# Month: October
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 21
#
#
# Year: 2024
#
# Month: October
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 16
#
#
# Year: 2024
#
# Month: October
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2024
#
# Month: September
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 155
#
#
# Year: 2024
#
# Month: September
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 144
#
#
# Year: 2024
#
# Month: September
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 63
#
#
# Year: 2024
#
# Month: September
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 165
#
#
# Year: 2024
#
# Month: September
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 174
#
#
# Year: 2024
#
# Month: September
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 140
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 17
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 11
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 3
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 19
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 22
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 20
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 407
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 412
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 156
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 489
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 223
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 189
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 43
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 39
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 16
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 46
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 24
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 269
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 272
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 111
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 266
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 310
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 160
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 44
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 27
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 9
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 28
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 41
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 21
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 305
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 276
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 102
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 293
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 344
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 179
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 21
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 21
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 6
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 34
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Transactions: 37
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Transactions: 13
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Transactions: 265
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Transactions: 266
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Books (General)
#
# Transactions: 92
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Transactions: 309
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Transactions: 245
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Textbooks
#
# Transactions: 77
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Transactions: 24
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Transactions: 27
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Transactions: 10
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Transactions: 22
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# ...
#
# Total Revenue: $455.56
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $63.50
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $236.06
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $13,737.87
#
#
# Year: 2024
#
# Month: September
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $3,755.12
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $12,929.77
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $13,034.82
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $4,480.54
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $4,856.19
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $102,381.40
#
#
# Year: 2025
#
# Month: April
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $32,895.31
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $1,320.91
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $1,323.39
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $397.90
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $526.29
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $14,331.42
#
#
# Year: 2025
#
# Month: April
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $2,255.99
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $8,361.80
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $9,028.96
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $2,998.39
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $2,709.34
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $161,517.13
#
#
# Year: 2025
#
# Month: August
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $26,359.36
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $1,636.29
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $700.57
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $322.76
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $271.72
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $27,996.19
#
#
# Year: 2025
#
# Month: August
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $3,525.06
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $9,668.70
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $8,728.44
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $3,320.63
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $2,953.44
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $154,975.51
#
#
# Year: 2025
#
# Month: December
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $29,740.80
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $690.90
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $673.08
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $332.52
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $328.89
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $18,522.38
#
#
# Year: 2025
#
# Month: December
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $2,151.90
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $9,009.19
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $8,239.09
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $2,918.32
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $3,067.68
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $131,269.65
#
#
# Year: 2025
#
# Month: February
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $12,443.31
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $821.09
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $723.61
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $305.42
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $204.30
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $13,681.84
#
#
# Year: 2025
#
# Month: February
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $796.53
#
#
# Year: 2025
#
# Month: January
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $11,060.32
#
#
# Year: 2025
#
# Month: January
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $10,937.61
#
#
# Year: 2025
#
# Month: January
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $3,653.60
#
#
# Year: 2025
#
# Month: January
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $3,888.98
#
#
# Year: 2025
#
# Month: January
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $138,621.67
#
#
# Year: 2025
#
# Month: January
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $14,284.15
#
#
# Year: 2025
#
# Month: January
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $859.93
#
#
# Year: 2025
#
# Month: January
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $1,497.40
#
#
# Year: 2025
#
# Month: January
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $246.22
#
#
# Year: 2025
#
# Month: January
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $343.66
#
#
# Year: 2025
#
# Month: January
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $17,063.79
#
#
# Year: 2025
#
# Month: January
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $762.36
#
#
# Year: 2025
#
# Month: July
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $9,013.64
#
#
# Year: 2025
#
# Month: July
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $7,006.09
#
#
# Year: 2025
#
# Month: July
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $3,243.61
#
#
# Year: 2025
#
# Month: July
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $2,958.09
#
#
# Year: 2025
#
# Month: July
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $156,807.08
#
#
# Year: 2025
#
# Month: July
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $26,449.08
#
#
# Year: 2025
#
# Month: July
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $1,187.08
#
#
# Year: 2025
#
# Month: July
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $673.00
#
#
# Year: 2025
#
# Month: July
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $357.20
#
#
# Year: 2025
#
# Month: July
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $224.84
#
#
# Year: 2025
#
# Month: July
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $16,204.38
#
#
# Year: 2025
#
# Month: July
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $3,362.95
#
#
# Year: 2025
#
# Month: June
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $14,545.92
#
#
# Year: 2025
#
# Month: June
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $12,492.81
#
#
# Year: 2025
#
# Month: June
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $4,565.54
#
#
# Year: 2025
#
# Month: June
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $4,538.95
#
#
# Year: 2025
#
# Month: June
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $99,140.64
#
#
# Year: 2025
#
# Month: June
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $33,683.38
#
#
# Year: 2025
#
# Month: June
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $1,209.11
#
#
# Year: 2025
#
# Month: June
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $713.82
#
#
# Year: 2025
#
# Month: June
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $334.86
#
#
# Year: 2025
#
# Month: June
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $328.95
#
#
# Year: 2025
#
# Month: June
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $9,566.61
#
#
# Year: 2025
#
# Month: June
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $3,376.15
#
#
# Year: 2025
#
# Month: March
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $9,456.37
#
#
# Year: 2025
#
# Month: March
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $9,994.92
#
#
# Year: 2025
#
# Month: March
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $3,839.40
#
#
# Year: 2025
#
# Month: March
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $3,185.88
#
#
# Year: 2025
#
# Month: March
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $136,640.48
#
#
# Year: 2025
#
# Month: March
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $21,365.70
#
#
# Year: 2025
#
# Month: March
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $916.69
#
#
# Year: 2025
#
# Month: March
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $1,039.53
#
#
# Year: 2025
#
# Month: March
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $344.10
#
#
# Year: 2025
#
# Month: March
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $292.52
#
#
# Year: 2025
#
# Month: March
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $15,424.32
#
#
# Year: 2025
#
# Month: March
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $1,815.35
#
#
# Year: 2025
#
# Month: May
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $14,308.74
#
#
# Year: 2025
#
# Month: May
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $13,736.48
#
#
# Year: 2025
#
# Month: May
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $5,341.24
#
#
# Year: 2025
#
# Month: May
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $4,509.87
#
#
# Year: 2025
#
# Month: May
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $118,406.29
#
#
# Year: 2025
#
# Month: May
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $31,827.87
#
#
# Year: 2025
#
# Month: May
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $1,135.43
#
#
# Year: 2025
#
# Month: May
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $1,048.60
#
#
# Year: 2025
#
# Month: May
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $351.40
#
#
# Year: 2025
#
# Month: May
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $449.41
#
#
# Year: 2025
#
# Month: May
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $10,266.14
#
#
# Year: 2025
#
# Month: May
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $2,051.17
#
#
# Year: 2025
#
# Month: November
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $8,109.53
#
#
# Year: 2025
#
# Month: November
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $8,613.07
#
#
# Year: 2025
#
# Month: November
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $3,130.52
#
#
# Year: 2025
#
# Month: November
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $2,916.37
#
#
# Year: 2025
#
# Month: November
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $175,539.20
#
#
# Year: 2025
#
# Month: November
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $23,062.18
#
#
# Year: 2025
#
# Month: November
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $755.64
#
#
# Year: 2025
#
# Month: November
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $827.52
#
#
# Year: 2025
#
# Month: November
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $282.69
#
#
# Year: 2025
#
# Month: November
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $208.75
#
#
# Year: 2025
#
# Month: November
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $14,612.87
#
#
# Year: 2025
#
# Month: November
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $1,994.25
#
#
# Year: 2025
#
# Month: October
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $13,414.30
#
#
# Year: 2025
#
# Month: October
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $11,842.20
#
#
# Year: 2025
#
# Month: October
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $4,909.59
#
#
# Year: 2025
#
# Month: October
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $4,294.84
#
#
# Year: 2025
#
# Month: October
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $257,001.19
#
#
# Year: 2025
#
# Month: October
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $40,580.50
#
#
# Year: 2025
#
# Month: October
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $1,203.05
#
#
# Year: 2025
#
# Month: October
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $1,581.61
#
#
# Year: 2025
#
# Month: October
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $504.50
#
#
# Year: 2025
#
# Month: October
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $482.76
#
#
# Year: 2025
#
# Month: October
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $19,232.43
#
#
# Year: 2025
#
# Month: October
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $4,627.64
#
#
# Year: 2025
#
# Month: September
#
# Territory: Colorado
#
# Category: Apparel and Merchandise
#
# Total Revenue: $8,783.94
#
#
# Year: 2025
#
# Month: September
#
# Territory: Colorado
#
# Category: Art Supplies
#
# Total Revenue: $8,328.27
#
#
# Year: 2025
#
# Month: September
#
# Territory: Colorado
#
# Category: Books (General)
#
# Total Revenue: $3,120.10
#
#
# Year: 2025
#
# Month: September
#
# Territory: Colorado
#
# Category: Stationery and Supplies
#
# Total Revenue: $2,523.57
#
#
# Year: 2025
#
# Month: September
#
# Territory: Colorado
#
# Category: Technology & Accessories
#
# Total Revenue: $150,733.42
#
#
# Year: 2025
#
# Month: September
#
# Territory: Colorado
#
# Category: Textbooks
#
# Total Revenue: $23,670.13
#
#
# Year: 2025
#
# Month: September
#
# Territory: South Carolina
#
# Category: Apparel and Merchandise
#
# Total Revenue: $687.56
#
#
# Year: 2025
#
# Month: September
#
# Territory: South Carolina
#
# Category: Art Supplies
#
# Total Revenue: $1,207.80
#
#
# Year: 2025
#
# Month: September
#
# Territory: South Carolina
#
# Category: Books (General)
#
# Total Revenue: $269.76
#
#
# Year: 2025
#
# Month: September
#
# Territory: South Carolina
#
# Category: Stationery and Supplies
#
# Total Revenue: $230.88
#
#
# Year: 2025
#
# Month: September
#
# Territory: South Carolina
#
# Category: Technology & Accessories
#
# Total Revenue: $12,642.82
#
#
# Year: 2025
#
# Month: September
#
# Territory: South Carolina
#
# Category: Textbooks
#
# Total Revenue: $1,561.70

# %% [markdown]
# ### Business Summary
#
# The monthly category analysis helps identify which product categories generate the highest transaction volume and sales revenue within the Colorado and South Carolina territories. Categories with consistently high transaction counts and strong monthly revenue likely represent the company’s most popular products and strongest-performing merchandise segments.
#
# Colorado is expected to generate significantly higher transaction volume and revenue because it consistently outperformed South Carolina in previous territory sales analyses. Product categories with lower transaction counts or weaker sales revenue may present opportunities for growth through additional marketing campaigns, inventory expansion, product promotions, or improved store placement strategies.
#
# Seasonal sales trends may also reveal months where certain product categories become more popular, helping management make better decisions related to forecasting, inventory management, and future business planning.

# %% [markdown]
# ### Monthly Transactions and Revenue by Product Category Chart

# %%
#________ Chart Notes ___________________________________________________________________________________________

# Import matplotlib.pyplot as plt to create charts and visualizations.
# Convert revenue_summary into a dataframe using .reset_index().
# .reset_index() converts the grouped index values into regular columns.
# Create a new Month_Year column by combining Month and Year columns together.
# This improves readability on the x-axis of the chart.
# Use a for loop to create a separate chart for Colorado and South Carolina.
# Filter the dataframe by State so each chart only displays one territory.
# Use .pivot_table() to reorganize the dataframe for plotting.
# The index becomes Month_Year for the x-axis values.
# The columns become product categories so each category becomes its own line.
# The values parameter uses Sale Amount to plot total revenue.
# Use .plot(kind="line") to create a line chart.
# marker="o" places dots on each data point.
# figsize controls the size of the chart window.
# plt.title(), plt.xlabel(), and plt.ylabel() add chart labels.
# plt.xticks(rotation=45) rotates labels for easier reading.
# plt.grid(True) adds grid lines to improve readability.
# plt.tight_layout() prevents labels from overlapping.
# plt.show() displays the completed chart.

#_______________________________________________________________________________________________________________

#________ Results Notes _________________________________________________________________________________________

# The charts display the monthly sales revenue generated by
# each product category within the Colorado and South Carolina territories.

# Colorado consistently shows higher revenue totals across
# most product categories, indicating stronger overall sales
# performance compared to South Carolina.

# Product categories with the highest and most consistent
# revenue lines likely represent the company’s most popular
# and profitable products.

# Large spikes in revenue during certain months may indicate
# seasonal purchasing trends or successful promotional periods.

# Categories with lower or inconsistent revenue may represent
# opportunities for future business growth through marketing,
# product expansion, or inventory adjustments.

# Comparing category performance between territories can help
# identify which products perform better in specific markets.

# The charts also help management visualize long-term sales
# trends and make data-driven decisions related to forecasting,
# budgeting, and inventory planning.

# If one category consistently outperforms others in both
# territories, it may deserve additional investment and
# promotional support.

# Categories with declining revenue trends may require further
# investigation to determine whether customer demand is changing.

#_______________________________________________________________________________________________________________
revenue_chart = (
    data_info.revenue_summary.reset_index())

# -------------------------------------------------
# Create combined Month-Year column
# -------------------------------------------------

revenue_chart["Month_Year"] = (
    revenue_chart["Month"] + " " +
    revenue_chart["Year"].astype(str))


# Create chart for each territory

for territory in ["Colorado", "South Carolina"]:

    # Filter territory data

    territory_chart = revenue_chart[
        revenue_chart["State"] == territory
    ]


    # Pivot data for plotting

    chart_pivot = territory_chart.pivot_table(
        index="Month_Year",
        columns="Category",
        values="Sale Amount",
        aggfunc="sum"
    )


    # Create line chart

    chart_pivot.plot(
        kind="line",
        marker="o",
        figsize=(15, 7)
    )


    # Chart labels

    mp.title(
        f"Monthly Revenue by Product Category - {territory}"
    )

    mp.xlabel("Month and Year")

    mp.ylabel("Total Revenue")

    mp.xticks(rotation=45)

    mp.grid(True)

    mp.tight_layout()

    mp.show()

# %% [markdown]
# ### What is your recommendation for where to focus marketing attention in the next quarter?

# %% [markdown]
# #### Business Recommendations
# Based on the analysis, I recommend focusing marketing efforts on the Colorado territory because it consistently generated the highest sales revenue and contained most of the top-performing stores. Marketing campaigns should emphasize high demand categories such as Technology & Accessories, Stationery and Supplies, and Textbooks while also using targeted promotions to increase sales in lower-performing categories. Additionally, expanding loyalty and customer retention programs around the highest-spending customers could help drive future revenue growth across both territories.
